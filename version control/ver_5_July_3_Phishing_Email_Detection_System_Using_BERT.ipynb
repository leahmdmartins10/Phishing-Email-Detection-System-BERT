# %%
import torch

#Set CPU as default device
default_device = torch.device("cpu")

#Set GPU for BERT training if available
bert_device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Default device for general processing: {default_device}")
print(f"Device for BERT training: {bert_device}")
# Out:
# Default device for general processing: cpu
# Device for BERT training: cuda

# %% [markdown]
# # 📧 Phishing Email Detection System Using BERT
#
# In this project, we aim to build a phishing email detection model using deep learning techniques, with a focus on the BERT (Bidirectional Encoder Representations from Transformers) architecture.
#
# Phishing emails are deceptive messages designed to trick users into revealing sensitive information. As attackers increasingly use AI to craft convincing emails, traditional rule-based filters fall short. This motivates the need for a more intelligent, language-aware detection system.
#
# We begin by loading and preprocessing real-world phishing and legitimate email datasets. After tokenizing the data, we will train and evaluate a fine-tuned BERT model, and compare its performance to a logistic regression baseline. Our objective is to build a model that accurately classifies emails as "phishing" or "safe" using language patterns and contextual understanding.

# %%
from google.colab import userdata
#KaggkeAPIKey = userdata.get('KaggleAPIKey')

# %% [markdown]
# ---
#
# # Mounting the google drive
# We have to mount the google drive seeing as the files for the datasets are stored there

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ---
# # Cleaning Data across Datasets
# Making all data sets consistent in labeling, data type and format:
#
# 1. "body": Holds the body of all emails.
# 2. "urls": Holds the boolean value for if a url is present or not (1: url, 0: no url)
# 3. "label": Holds the boolen value for if an email is Phishing or Safe (1: phishing, 0 not phishing)
#
#
# - REMOVING UNPARSABLE/ ILLEGAL DATA
# - You can view all data at "APS360_Final_Cleaned_Data" in shared folder

# %%
# !pip install xlsxwriter
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.11/dist-packages (3.2.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os
import pandas as pd
import re

#Folder with your CSVs
source_folder = '/content/drive/MyDrive/APS360 Notes/Datasets'
output_excel_path = os.path.join(source_folder, 'APS360_Final_Cleaned_Data.xlsx')

#Create the directory if it doesn't exist
os.makedirs(source_folder, exist_ok=True)

#Patterns to detect illegal Excel characters and ANSI sequences
ansi_pattern = re.compile(r'[\x1B\x1b]\[[0-9;]*[A-Za-z]|[0-9]+;[0-9]+[Hf]')
illegal_excel_chars = re.compile(r"[\x00-\x08\x0B-\x1F]")

#Function to check if a row contains illegal characters
def row_has_illegal_data(row):
    return any(
        ansi_pattern.search(str(cell)) or illegal_excel_chars.search(str(cell))
        for cell in row
    )

#Create ExcelWriter object
with pd.ExcelWriter(output_excel_path, engine='openpyxl') as writer:
    for filename in os.listdir(source_folder):
        if filename.endswith('.csv'):
            filepath = os.path.join(source_folder, filename)

            try:
                df = pd.read_csv(filepath, on_bad_lines='skip', encoding='utf-8', engine='python')
            except Exception as e:
                print(f"Skipping {filename} due to read error: {e}")
                continue

            #Drop rows with illegal characters
            df = df[~df.apply(row_has_illegal_data, axis=1)]

            #Clean and rename columns
            df.columns = [col.strip() for col in df.columns]
            col_map = {}
            for col in df.columns:
                if col.lower() in ['email text', 'text']:
                    col_map[col] = 'body'
                elif col.lower() == 'email type':
                    col_map[col] = 'label'
            df = df.rename(columns=col_map)

            #Add 'urls' column if missing
            if 'urls' not in df.columns and 'body' in df.columns:
                df['urls'] = df['body'].astype(str).apply(lambda x: 1 if 'http' in x else 0)

            #Keep only ['body', 'urls', 'label']
            keep_cols = [col for col in ['body', 'urls', 'label'] if col in df.columns]
            df = df[keep_cols]

            #Write sheet to Excel
            sheet_name = os.path.splitext(filename)[0][:31]
            try:
                df.to_excel(writer, sheet_name=sheet_name, index=False)
            except Exception as e:
                print(f"Failed to write sheet for {filename}: {e}")

print(f"Done! Cleaned Excel file saved at:\n{output_excel_path}")
# Out:
# Done! Cleaned Excel file saved at:
# /content/drive/MyDrive/APS360 Notes/Datasets/APS360_Final_Cleaned_Data.xlsx

# %% [markdown]
# ---
# #Combine Data into One Large Dataset
#
# - Takes all csv files and merges into one giant data set.
# - Removes empty and null rows.
# - Randomly shuffles and rearranges data.
# - Makes sure that "label" and "urls" data is numerical later processing

# %%
#This is a function Force string/int labels to integer 0 or 1
#Will be used later in combination (for cleaning purposes)

def clean_numerics(x):
    x_str = str(x).strip().lower()
    if x_str in ['1', 'phishing email']:
        return 1
    elif x_str in ['0', 'safe email']:
        return 0
    else:
        return 0

# %%
#Load all sheets
all_sheets = pd.read_excel(output_excel_path, sheet_name=None)

#Concatenate all sheets into one DataFrame
phishing_df = pd.concat(all_sheets.values(), ignore_index=True)

#Drop rows with missing values (if any)
phishing_df = phishing_df.dropna()

#Shuffle dataset
phishing_df = phishing_df.sample(frac=1, random_state=42).reset_index(drop=True)

#Checks that this data is numerical
phishing_df['label'] = phishing_df['label'].apply(clean_numerics)
phishing_df['urls'] = phishing_df['urls'].apply(clean_numerics)

# %% [markdown]
# ---
# #Split Tensor Data into Training Validation and Testing Datasets
#
# - Randomly split the encoded email data into 70% training, 15% validation, and 15% test sets.
# - Each split contains input tensors from the tokenization (input_ids, attention_mask) along with corresponding labels and URL indicators (from phishing_df ).
# - This prepares the data for use in training and evaluating an AI classification model.

# %%
from sklearn.model_selection import train_test_split
import torch

#Convert labels and urls to tensors
label = torch.tensor(phishing_df['label'].values)
urls = torch.tensor(phishing_df['urls'].values)

#First split into training data for 70% and temp data (vaidation + testing) for 30%
train_idx, temp_idx = train_test_split(range(len(label)), test_size=0.3, random_state=42)

#Then split temp into validation and testing 15% each
val_idx, test_idx = train_test_split(temp_idx, test_size=0.5, random_state=42)

# %%
# splitting the bodies for train, val, and test data
train_bodies = phishing_df['body'][train_idx].tolist()
val_bodies = phishing_df['body'][val_idx].tolist()
test_bodies = phishing_df['body'][test_idx].tolist()

# converting the training, val, and test urls and labels to tensors
train_urls = torch.tensor(phishing_df['urls'][train_idx].tolist())
train_labels = torch.tensor(phishing_df['label'][train_idx].tolist())


val_urls = torch.tensor(phishing_df['urls'][val_idx].tolist())
val_labels = torch.tensor(phishing_df['label'][val_idx].tolist())


test_urls = torch.tensor(phishing_df['urls'][test_idx].tolist())
test_labels = torch.tensor(phishing_df['label'][test_idx].tolist())

# %% [markdown]
# ---
# # **Tokenize the training, validation, and testing bodies**
# We are now tokenizing the data that we have previously split.
#
# We are creating classes that define how to tokenize the data but this will not actually occur until the BERT model is used. The class highlights the main functionality:
#
#
# **Initialization**: Initialize the dataset with text data, URLs, labels, and tokenizer.
#
#         Args:
#         - texts (List[str]): List of email bodies.
#         - urls (List[str] or similar): Corresponding list of URLs in the emails.
#         - labels (List[int]): Labels (e.g., 0 for ham, 1 for phishing).
#         - tokenizer (BertTokenizer): Pretrained BERT tokenizer.
#         - max_length (int): Maximum sequence length for padding/truncation.
#
#
# **Retrival/Tokenization:** Retrieve a single sample from the dataset and tokenize it.
#
#         Args:
#         - idx (int): Index of the sample to fetch.
#
#         Returns:
#         - A dictionary containing:
#           - 'input_ids': token IDs for the text
#           - 'attention_mask': binary mask for padded tokens
#           - 'urls': original URL
#           - 'labels': ground truth label

# %%
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer

#Load the pretrained BERT tokenizer (lowercase version of BERT)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

#Define a custom dataset class for phishing email detection
class PhishingEmailDataset(Dataset):
    def __init__(self, texts, urls, labels, tokenizer, max_length=256):
        #Initialize the dataset with text data, URLs, labels, and tokenizer.
        self.texts = texts
        self.urls = urls
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        #Return the total number of samples in the dataset
        return len(self.texts)

    def __getitem__(self, idx):

        #Retrieve a single sample from the dataset and tokenize it.

        encoding = self.tokenizer(
            self.texts[idx],              #The email body
            truncation=True,             #Truncate if it exceeds max_length
            padding='max_length',        #Pad to max_length
            max_length=self.max_length,  #Set max sequence length
            return_tensors='pt'          #Return PyTorch tensors
        )
        return {
            'input_ids': encoding['input_ids'].squeeze(),            #Token IDs (squeezed to remove extra dimension)
            'attention_mask': encoding['attention_mask'].squeeze(),  #Attention mask (squeezed)
            'urls': self.urls[idx],                                  #Corresponding URL
            'labels': self.labels[idx]                               #Label for classification
        }

#These assume you have train_bodies, train_urls, and train_labels already defined
train_dataset = PhishingEmailDataset(train_bodies, train_urls, train_labels, tokenizer)
val_dataset   = PhishingEmailDataset(val_bodies, val_urls, val_labels, tokenizer)
test_dataset  = PhishingEmailDataset(test_bodies, test_urls, test_labels, tokenizer)


batch_size = 8  #Number of samples per batch

#For training
train_loader = DataLoader(
    train_dataset,
    sampler=RandomSampler(train_dataset),
    batch_size=batch_size
)

#For validation and testing
val_loader = DataLoader(
    val_dataset,
    sampler=RandomSampler(val_dataset),
    batch_size=batch_size
)

test_loader = DataLoader(
    test_dataset,
    sampler=RandomSampler(test_dataset),
    batch_size=batch_size
)

# %% [markdown]
# ---
# # **Converting the Tokenized Data to Complete Tensors**

# %% [markdown]
# # Tokenization for Logisitic Regression
#
# This implementation of tokenization will be used specifically for the logistic regression model. The implementation steps include:
#   1. Vectorizing the sentences
#   2. Counting the occurances of words
#   3. Vectorizing the numbers for the corresponding words

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(ngram_range=(1,3))

train_bow = vectorizer.fit_transform(train_bodies)
val_bow = vectorizer.transform(val_bodies)
test_bow = vectorizer.transform(test_bodies)

# %% [markdown]
# # **Implementing the Logistic Regression Model**
# add description here after

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Initialize Logistic Regression with suitable parameters
log_reg = LogisticRegression(max_iter=1000, random_state=42)

# Fit the model on Bag-of-Words training data
log_reg.fit(train_bow, train_labels.numpy())

# Predict on validation set
val_preds = log_reg.predict(val_bow)

# Calculate validation accuracy
val_accuracy = accuracy_score(val_labels.numpy(), val_preds)
print(f"Validation Accuracy (Logistic Regression Baseline): {val_accuracy * 100:.2f}%")
# Out:
# Validation Accuracy (Logistic Regression Baseline): 98.44%

# %% [markdown]
# ---
# #**Apply Pretrained BERT Model**
#
# - Initialize Pretrained BERT Model Transformer
# - Use AdamW Optimizer for optimization and loss
# - Define Dataloaders from tensors
# - Train the Model
# - Use Early Stopping in pretrained model

# %%
"""Initialize Pretrained BERT Model Transformer"""

from transformers import BertForSequenceClassification

model = BertForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels=2  # Binary classification
)


import torch

# Set up device (GPU if available, else CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Move model to device
model = model.to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using device: cuda

# %%
"""Use AdamW Optimizer for optimization and loss"""
from torch.optim import AdamW

optimizer = AdamW(model.parameters(), lr=1e-5, weight_decay=2e-5)

# %%
import matplotlib.pyplot as plt
from transformers import get_linear_schedule_with_warmup

epochs=3
#Initialize optimizer WITH weight decay
optimizer = AdamW(model.parameters(), lr=2e-5, weight_decay=1e-5)

#Scheduler setup (optional but recommended for BERT)
total_steps = len(train_loader) * epochs
scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=int(0.1 * total_steps),
    num_training_steps=total_steps
)

#Early stopping vars
best_val_loss = float('inf')
patience = 2  #how many bad epochs before stopping
patience_counter = 0

train_loss_list = []
val_loss_list = []
train_err_list = []
val_err_list = []

epochs = 3
for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    total_train_err = 0

    for step, batch in enumerate(train_loader):
        b_input_ids = batch['input_ids'].to(bert_device)
        b_attention_mask = batch['attention_mask'].to(bert_device)
        b_labels = batch['labels'].to(bert_device)

        optimizer.zero_grad()

        outputs = model(input_ids=b_input_ids, attention_mask=b_attention_mask, labels=b_labels)
        loss = outputs.loss
        logits = outputs.logits

        loss.backward()
        optimizer.step()
        scheduler.step()  #add scheduler step after optimizer step

        total_train_loss += loss.item()

        preds = logits.argmax(dim=1)
        total_train_err += (preds != b_labels).sum().item()

        print(f"Epoch {epoch+1}, Batch {step+1}/{len(train_loader)} completed. Batch loss: {loss.item():.4f}")

    avg_train_loss = total_train_loss / len(train_loader)
    train_error = total_train_err / len(train_loader.dataset)

    train_loss_list.append(avg_train_loss)
    train_err_list.append(train_error)

    #Validation phase
    model.eval()
    total_val_loss = 0
    total_val_err = 0
    with torch.no_grad():
        for batch in val_loader:
            b_input_ids = batch['input_ids'].to(bert_device)
            b_attention_mask = batch['attention_mask'].to(bert_device)
            b_labels = batch['labels'].to(bert_device)

            outputs = model(input_ids=b_input_ids, attention_mask=b_attention_mask, labels=b_labels)
            loss = outputs.loss
            logits = outputs.logits

            total_val_loss += loss.item()
            preds = logits.argmax(dim=1)
            total_val_err += (preds != b_labels).sum().item()

    avg_val_loss = total_val_loss / len(val_loader)
    val_error = total_val_err / len(val_loader.dataset)

    val_loss_list.append(avg_val_loss)
    val_err_list.append(val_error)

    print(f"Epoch {epoch+1} done. Train loss: {avg_train_loss:.4f}, Val loss: {avg_val_loss:.4f}, Train err: {train_error:.4f}, Val err: {val_error:.4f}")

    #Early stopping check
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        patience_counter = 0
        torch.save(model.state_dict(), 'best_model.pt')  #Save best model
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered!")
            break
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 3, Batch 876/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 877/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 878/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 879/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 880/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 881/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 882/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 883/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 884/5874 completed. Batch loss: 0.1234
# Epoch 3, Batch 885/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 886/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 887/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 888/5874 completed. Batch loss: 0.0300
# Epoch 3, Batch 889/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 890/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 891/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 892/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 893/5874 completed. Batch loss: 0.0007
# Epoch 3, Batch 894/5874 completed. Batch loss: 0.1179
# Epoch 3, Batch 895/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 896/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 897/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 898/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 899/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 900/5874 completed. Batch loss: 0.0005
# Epoch 3, Batch 901/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 902/5874 completed. Batch loss: 0.1181
# Epoch 3, Batch 903/5874 completed. Batch loss: 0.1123
# Epoch 3, Batch 904/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 905/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 906/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 907/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 908/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 909/5874 completed. Batch loss: 0.0317
# Epoch 3, Batch 910/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 911/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 912/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 913/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 914/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 915/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 916/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 917/5874 completed. Batch loss: 0.0003
# Epoch 3, Batch 918/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 919/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 920/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 921/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 922/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 923/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 924/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 925/5874 completed. Batch loss: 0.0059
# Epoch 3, Batch 926/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 927/5874 completed. Batch loss: 0.0014
# Epoch 3, Batch 928/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 929/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 930/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 931/5874 completed. Batch loss: 0.0008
# Epoch 3, Batch 932/5874 completed. Batch loss: 0.0713
# Epoch 3, Batch 933/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 934/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 935/5874 completed. Batch loss: 0.0507
# Epoch 3, Batch 936/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 937/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 938/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 939/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 940/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 941/5874 completed. Batch loss: 0.0003
# Epoch 3, Batch 942/5874 completed. Batch loss: 0.0003
# Epoch 3, Batch 943/5874 completed. Batch loss: 0.0008
# Epoch 3, Batch 944/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 945/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 946/5874 completed. Batch loss: 0.0009
# Epoch 3, Batch 947/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 948/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 949/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 950/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 951/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 952/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 953/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 954/5874 completed. Batch loss: 0.0016
# Epoch 3, Batch 955/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 956/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 957/5874 completed. Batch loss: 0.0007
# Epoch 3, Batch 958/5874 completed. Batch loss: 0.0003
# Epoch 3, Batch 959/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 960/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 961/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 962/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 963/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 964/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 965/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 966/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 967/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 968/5874 completed. Batch loss: 0.0005
# Epoch 3, Batch 969/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 970/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 971/5874 completed. Batch loss: 0.0012
# Epoch 3, Batch 972/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 973/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 974/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 975/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 976/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 977/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 978/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 979/5874 completed. Batch loss: 0.0004
# Epoch 3, Batch 980/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 981/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 982/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 983/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 984/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 985/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 986/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 987/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 988/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 989/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 990/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 991/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 992/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 993/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 994/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 995/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 996/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 997/5874 completed. Batch loss: 0.1471
# Epoch 3, Batch 998/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 999/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 1000/5874 completed. Batch loss: 0.0005
# Epoch 3, Batch 1001/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 1002/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 
5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5714/5874 completed. Batch loss: 0.0576
# Epoch 3, Batch 5715/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5716/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5717/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5718/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5719/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5720/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5721/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5722/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5723/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5724/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5725/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5726/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5727/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5728/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5729/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5730/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5731/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5732/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 5733/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5734/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5735/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5736/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5737/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5738/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5739/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5740/5874 completed. Batch loss: 0.1225
# Epoch 3, Batch 5741/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5742/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5743/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5744/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5745/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5746/5874 completed. Batch loss: 0.0592
# Epoch 3, Batch 5747/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5748/5874 completed. Batch loss: 0.1411
# Epoch 3, Batch 5749/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5750/5874 completed. Batch loss: 0.1283
# Epoch 3, Batch 5751/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5752/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5753/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5754/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5755/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5756/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5757/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5758/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5759/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5760/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5761/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5762/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5763/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5764/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5765/5874 completed. Batch loss: 0.0488
# Epoch 3, Batch 5766/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5767/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5768/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5769/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5770/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5771/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5772/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5773/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5774/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5775/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5776/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5777/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5778/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5779/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5780/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5781/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5782/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5783/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5784/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5785/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5786/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5787/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5788/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5789/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5790/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5791/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5792/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5793/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5794/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5795/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5796/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5797/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5798/5874 completed. Batch loss: 0.1253
# Epoch 3, Batch 5799/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5800/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5801/5874 completed. Batch loss: 0.0106
# Epoch 3, Batch 5802/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5803/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5804/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5805/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5806/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5807/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5808/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5809/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5810/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5811/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5812/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5813/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5814/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5815/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 5816/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5817/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5818/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5819/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5820/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5821/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5822/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5823/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5824/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5825/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5826/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5827/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5828/5874 completed. Batch loss: 0.0008
# Epoch 3, Batch 5829/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5830/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5831/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5832/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5833/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5834/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5835/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5836/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5837/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5838/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5839/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5840/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5841/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5842/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5843/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5844/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5845/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 5846/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5847/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5848/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5849/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5850/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5851/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5852/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5853/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5854/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5855/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5856/5874 completed. Batch loss: 0.1209
# Epoch 3, Batch 5857/5874 completed. Batch loss: 0.0002
# Epoch 3, Batch 5858/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5859/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5860/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5861/5874 completed. Batch loss: 0.0001
# Epoch 3, Batch 5862/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5863/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5864/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5865/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5866/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5867/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5868/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5869/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5870/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5871/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5872/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5873/5874 completed. Batch loss: 0.0000
# Epoch 3, Batch 5874/5874 completed. Batch loss: 0.0000
# Epoch 3 done. Train loss: 0.0073, Val loss: 0.0306, Train err: 0.0036, Val err: 0.0084

# %%
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(12,5))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_loss_list, label='Train Loss')
plt.plot(epochs_range, val_loss_list, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over epochs')
plt.legend()

# Plot error
plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_err_list, label='Train Error')
plt.plot(epochs_range, val_err_list, label='Val Error')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.title('Error over epochs')
plt.legend()

plt.show()

# %% [markdown]
# # Cleaning up RAM usage **(Place this block at the bottom of the code for now please)**
# We are going to clean up some data to prevent high usage of memory. Please note, you can only run this cell once if you don't reinstantiate these variables

# %%
import gc

del phishing_df

del train_bodies, val_bodies, test_bodies

del tokenizedTraining, tokenizedValidation, tokenizedTest

gc.collect()
